# %% [markdown]
# ## Pandas Functions

# %%
1. df["Col_name"].unique()
2. df["col_name"].nunique()
3. df["col_name"].value_counts()
4. pd.crosstab(col1, col2)
5. df.replace({"str1":"str2"}) or df.replace({num1:num2}) ## Can be applied dataframe and series
6. df.['col_name'].astype(dtype)

Sorting Function:
    1. df.sort_values()
    2. df.sort_index()
    3. df.reset_index()
    4. df.set_index()

# %%
import pandas as pd  ### There are no secrete ingredient!!
import numpy as np

# %%
df = pd.read_excel("Emp_Records.xlsx")

# %%
df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     0
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
pd.set_option("display.max_columns",None) ## To visualise all the columns

# %%
# pd.set_option("display.max_rows",None) ## To visualise all the rows

# %%
df.shape
# Out:
# (100, 7)

# %%
df.set_index("Emp ID") ## Inplace is set to False
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 677509       Lois       36.36             60           13.68  168251
# 940761     Brenda       47.02             60            9.01   51063
# 428945        Joe       54.15             68            0.98   50155
# 408351      Diane       39.67             51           18.30  180294
# 193819   Benjamin       40.31             58            4.01  117642
# ...           ...         ...            ...             ...     ...
# 639892       Jose       22.82             89            1.05  129774
# 704709     Harold       32.61             77            5.93  156194
# 461593     Nicole       52.66             60           28.53   95673
# 392491    Theresa       29.60             57            6.99   51015
# 495141      Tammy       38.38             55            2.26   93650
#
#                 City
# Emp ID
# 677509        Denver
# 940761     Stonewall
# 428945  Michigantown
# 408351      Hydetown
# ...

# %%
df.head() ## Since in above operation inplace was false, no change can be seen in actual dataframe
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 677509       Lois       36.36             60           13.68  168251
# 940761     Brenda       47.02             60            9.01   51063
# 428945        Joe       54.15             68            0.98   50155
# 408351      Diane       39.67             51           18.30  180294
# 193819   Benjamin       40.31             58            4.01  117642
#
#                 City
# Emp ID
# 677509        Denver
# 940761     Stonewall
# 428945  Michigantown
# 408351      Hydetown
# 193819       Fremont

# %%
df.set_index("Emp ID", inplace = True)

# %%
df.head()
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 677509       Lois       36.36             60           13.68  168251
# 940761     Brenda       47.02             60            9.01   51063
# 428945        Joe       54.15             68            0.98   50155
# 408351      Diane       39.67             51           18.30  180294
# 193819   Benjamin       40.31             58            4.01  117642
#
#                 City
# Emp ID
# 677509        Denver
# 940761     Stonewall
# 428945  Michigantown
# 408351      Hydetown
# 193819       Fremont

# %%
df.sort_index(inplace = True)

# %%
df.head()
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 134841      Donna       33.89             57            4.03  129836
# 153989       Jack       22.21             61            0.56   82965
# 158666    Rebecca       56.00             55           34.32  160043
# 162402      Diana       29.73             60            3.44   43010
# 183071     Andrea       32.08             52            7.28   54179
#
#                   City
# Emp ID
# 134841            Lima
# 153989       Las Vegas
# 158666    Independence
# 162402  Eureka Springs
# 183071         Granger

# %%
df.reset_index(inplace = True) ## Reset Index

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   134841      Donna       33.89             57            4.03  129836
# 1   153989       Jack       22.21             61            0.56   82965
# 2   158666    Rebecca       56.00             55           34.32  160043
# 3   162402      Diana       29.73             60            3.44   43010
# 4   183071     Andrea       32.08             52            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 95  958326      Larry       28.76             75            0.43   97904
# 96  969580    Matthew       23.77             56            1.47   52237
# 97  969964     Janice       37.57             56            0.93  147641
# 98  971640   Clarence       56.66             64            8.58  165272
# 99  979607      Carol       22.64             56            1.26   93967
#
#                        City
# 0                      Lima
# 1                 Las Vegas
# ...

# %%
df.sort_values(by = ["Age in Yrs"])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 22  301576      Wayne       21.10             87            0.02   92758
# 82  879753     Pamela       21.30             47            0.13  149262
# 71  750173    Antonio       21.93             82            0.24  181646
# 57  539712      Nancy       22.14             50            0.87   98189
# 1   153989       Jack       22.21             61            0.56   82965
# ..     ...        ...         ...            ...             ...     ...
# 55  528673       Paul       58.43             60           22.10  145235
# 29  380086      Carol       59.12             40           34.52   60918
# 51  515103       Anne       59.27             48           14.01  114426
# 58  560455    Carolyn       59.42             53           16.08   42005
# 38  441771     Cheryl       59.47             47           26.69   92220
#
#            City
# 22        Maida
# 82       Banner
# 71     Mc Calla
# 57      Atlanta
# ...

# %%
df_sorted = df.sort_values("Age in Yrs")

# %%
df_sorted.head()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 22  301576      Wayne       21.10             87            0.02   92758
# 82  879753     Pamela       21.30             47            0.13  149262
# 71  750173    Antonio       21.93             82            0.24  181646
# 57  539712      Nancy       22.14             50            0.87   98189
# 1   153989       Jack       22.21             61            0.56   82965
#
#          City
# 22      Maida
# 82     Banner
# 71   Mc Calla
# 57    Atlanta
# 1   Las Vegas

# %%
df_sorted_by_age_weight = df.sort_values(["Age in Yrs","Weight in Kgs"])
df_sorted_by_age_weight
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 22  301576      Wayne       21.10             87            0.02   92758
# 82  879753     Pamela       21.30             47            0.13  149262
# 71  750173    Antonio       21.93             82            0.24  181646
# 57  539712      Nancy       22.14             50            0.87   98189
# 1   153989       Jack       22.21             61            0.56   82965
# ..     ...        ...         ...            ...             ...     ...
# 55  528673       Paul       58.43             60           22.10  145235
# 29  380086      Carol       59.12             40           34.52   60918
# 51  515103       Anne       59.27             48           14.01  114426
# 58  560455    Carolyn       59.42             53           16.08   42005
# 38  441771     Cheryl       59.47             47           26.69   92220
#
#            City
# 22        Maida
# 82       Banner
# 71     Mc Calla
# 57      Atlanta
# ...

# %%
df_sorted_by_weight_salary = df.sort_values(["Weight in Kgs", "Salary"])
df_sorted_by_weight_salary
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 29  380086      Carol       59.12             40           34.52   60918
# 74  765850      Linda       25.96             40            0.20  113256
# 12  227922     Amanda       35.02             40           10.28  114257
# 52  524896       Judy       56.38             40            5.59  133332
# 42  474599      Maria       42.39             41           18.84   48944
# ..     ...        ...         ...            ...             ...     ...
# 22  301576      Wayne       21.10             87            0.02   92758
# 62  623929      Jimmy       50.70             87            9.63  120631
# 73  761821     Ernest       32.77             87            2.49  176675
# 63  639892       Jose       22.82             89            1.05  129774
# 69  726264       Carl       43.63             90           10.14  162159
#
#             City
# 29   Blanchester
# 74        Albion
# 12  Lake Charles
# 52        Topeka
# ...

# %%
df_sorted_by_weight_salary = df.sort_values(["Weight in Kgs", "Salary"],ascending=False )
df_sorted_by_weight_salary
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 69  726264       Carl       43.63             90           10.14  162159
# 63  639892       Jose       22.82             89            1.05  129774
# 73  761821     Ernest       32.77             87            2.49  176675
# 62  623929      Jimmy       50.70             87            9.63  120631
# 22  301576      Wayne       21.10             87            0.02   92758
# ..     ...        ...         ...            ...             ...     ...
# 42  474599      Maria       42.39             41           18.84   48944
# 52  524896       Judy       56.38             40            5.59  133332
# 12  227922     Amanda       35.02             40           10.28  114257
# 74  765850      Linda       25.96             40            0.20  113256
# 29  380086      Carol       59.12             40           34.52   60918
#
#             City
# 69        Wright
# 63        Biloxi
# 73  Saranac Lake
# 62      Oriskany
# ...
